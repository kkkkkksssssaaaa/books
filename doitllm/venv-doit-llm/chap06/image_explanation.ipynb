# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

client = OpenAI(api_key=api_key)

messages = [
  {
    "role": "user",
    "content": [
      {
        "type": "text",
        "text": "이 이미지에 대해 설명해 주세요."
      },
      {
        "type": "image_url",
        "image_url": {
          "url": "https://img-cdn.theqoo.net/pQeIPP.jpg"
        }
      }
    ]
  }
]

response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=messages,
)

response
# Out:
# ChatCompletion(id='chatcmpl-Byffe9l6xKLKbSalja1AxLuBJcDL6', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='이미지에는 한 여성의 모습이 담겨 있습니다. 그녀는 화려한 의상을 입고 있으며, 단정한 헤어스타일과 우아한 액세서리로 장식되어 있습니다. 배경은 흐릿하지만 따뜻한 느낌을 주며, 화면 하단에는 "LATE AUTUMN"이라는 문구가 크게 적혀 있습니다. 전체적으로 고급스럽고 세련된 분위기를 풍깁니다.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))], created=1753799562, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_62a23a81ef', usage=CompletionUsage(completion_tokens=94, prompt_tokens=25516, total_tokens=25610, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
import base64

def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

image_path = "./황녀.jpg"
encoded_image = encode_image(image_path)

print(encoded_image)
# Out:
# ...

# %%
messages = [
  {
    "role": "user",
    "content": [
      {
        "type": "text",
        "text": "이 이미지에 대해 설명해 주세요."
      },
      {
        "type": "image_url",
        "image_url": {
          "url": f"data:image/jpeg;base64,{encoded_image}"
        }
      }
    ]
  }
]

response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=messages,
)

response.choices[0].message.content
# Out:
# '이미지에는 한 여성의 모습이 담겨 있습니다. 그녀는 화려한 의상을 입고 있으며, 부드러운 컬이 진 헤어스타일을 하고 있습니다. 얼굴에는 자연스러운 메이크업이 되어 있으며, 립스틱이 돋보이는 것 같습니다. 배경에는 따뜻한 조명이 비치고 있어 그녀의 표정이 더욱 부각됩니다. 이미지의 하단에는 "LATE AUTUMN"이라는 텍스트가 적혀 있습니다. 전체적으로 우아하고 매혹적인 분위기를 자아내는 장면입니다.'

# %%
gaeul_legend_base64 = encode_image("./황녀.jpg")
gaeul_legend_2_base64 = encode_image("./황녀2.jpg")

messages = [
  {
    "role": "user",
    "content": [
      {
        "type": "text",
        "text": "이 이미지에 대해 설명해 주세요."
      },
      {
        "type": "image_url",
        "image_url": {
          "url": f"data:image/jpeg;base64,{gaeul_legend_base64}"
        }
      },
      {
        "type": "image_url",
        "image_url": {
          "url": f"data:image/jpeg;base64,{gaeul_legend_2_base64}"
        }
      }
    ]
  }
]

response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=messages,
)

response.choices[0].message.content
# Out:
# '이미지에서 볼 수 있는 인물은 화려한 흰색 드레스를 입고 있으며, 에둘러 장식된 디자인이 특징입니다. 헤어스타일은 부드럽고 자연스럽게 흘러내리며, 머리의 한 쪽에는 작은 꽃 장식이 있습니다. 두 사진 모두 표정이 밝고 친근하게 보이며, 첫 번째 사진은 좀 더 진중한 표정이고, 두 번째 사진은 미소를 짓고 포즈를 취하고 있습니다. 배경은 흐릿하게 처리되어 있어, 인물이 돋보이도록 하고 있습니다. "LATE AUTUMN"이라는 텍스트가 첫 번째 이미지에 포함되어 있습니다.'
